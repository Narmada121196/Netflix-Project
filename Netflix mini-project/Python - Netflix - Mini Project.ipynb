# %% [markdown]
# #                                         # NETFLIX MINI PROJECT

# %% [markdown]
# ## Netflix Data Analysis::
# You have been provided a dataset of Netflix which consists of TV shows and movies available on
# Netflix as of 2019. The dataset is collected from Flixable which is a third-party Netflix search engine.
# In 2018, they released an interesting report which shows that the number of TV shows on Netflix has
# nearly tripled since 2010. The streaming service’s number of movies has decreased by more than
# 2,000 titles since 2010, while its number of TV shows has nearly tripled.
# Before performing any analysis on this data, you are requested to import the data in Python and
# clean the data.
# ##### Task 1: Plot a graph showing number of contents on Netflix based on Rating.
# ##### Task 2: Plot a graph showing the number of TV Shows and Movies across different type of Rating.
# ##### Task 3: Compare India, US, Japan, Spain, UK & Canada to check which country produces highest TV Show and Movies.
# ##### Task 4: Plot a graph showing the number of TV Shows and Movies added to Netflix every year.
# ##### Task 5: In 2019, Find out if Netflix has added more TV Shows or Movies to their platform and represent the same visually.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import  matplotlib as mlp
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("netflix_titles_nov_2019.csv")

# %%
df.head()
# Out:
#     show_id                                title                    director  \
# 0  81193313                            Chocolate                         NaN
# 1  81197050  Guatemala: Heart of the Mayan World  Luis Ara, Ignacio Jaunsolo
# 2  81213894                      The Zoya Factor             Abhishek Sharma
# 3  81082007                            Atlantics                   Mati Diop
# 4  80213643                      Chip and Potato                         NaN
#
#                                                 cast  \
# 0  Ha Ji-won, Yoon Kye-sang, Jang Seung-jo, Kang ...
# 1                                  Christian Morales
# 2  Sonam Kapoor, Dulquer Salmaan, Sanjay Kapoor, ...
# 3  Mama Sane, Amadou Mbow, Ibrahima Traore, Nicol...
# 4  Abigail Oliver, Andrea Libman, Briana Buckmast...
#
#                     country         date_added  release_year rating  \
# 0               South Korea  November 30, 2019          2019  TV-14
# ...

# %%
df.columns
# Out:
# Index(['show_id', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description',
#        'type'],
#       dtype='object')

# %%
df.describe()
# Out:
#             show_id  release_year
# count  5.837000e+03   5837.000000
# mean   7.730079e+07   2013.688539
# std    9.479777e+06      8.419088
# min    2.698800e+05   1925.000000
# 25%    8.004520e+07   2013.000000
# 50%    8.016353e+07   2016.000000
# 75%    8.024188e+07   2018.000000
# max    8.122720e+07   2020.000000

# %%
df.isna().sum()
# Out:
# show_id            0
# title              0
# director        1901
# cast             556
# country          427
# date_added       642
# release_year       0
# rating            10
# duration           0
# listed_in          0
# description        0
# type               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5837 entries, 0 to 5836
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       5837 non-null   int64
#  1   title         5837 non-null   object
#  2   director      3936 non-null   object
#  3   cast          5281 non-null   object
#  4   country       5410 non-null   object
#  5   date_added    5195 non-null   object
#  6   release_year  5837 non-null   int64
#  7   rating        5827 non-null   object
#  8   duration      5837 non-null   object
#  9   listed_in     5837 non-null   object
#  10  description   5837 non-null   object
#  11  type          5837 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 547.3+ KB

# %%
df.isna().sum().sum()
# Out:
# 3536

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [show_id, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, type]
# Index: []

# %%
df.isna().sum().plot(kind = 'bar')
# Out:
# <Axes: >

# %%
#The fillna() method replaces the NULL values with a specified value. 
df['director'].fillna('No Director', inplace = True)

# %%
df['director'].isnull().sum()
# Out:
# 0

# %%
df['cast'].fillna('No cast', inplace = True)

# %%
df['country'].fillna('No Country given', inplace = True)

# %%
###dropna() method removes the rows that contains NULL values.
df.dropna(subset=["date_added", "rating"], inplace=True)

# %%
df.isna().sum()
# Out:
# show_id         0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# type            0
# dtype: int64

# %% [markdown]
# #### Task 1: Plot a graph showing number of contents on Netflix based on Rating.

# %%
df['rating'].value_counts()
# Out:
# TV-MA       1722
# TV-14       1406
# TV-PG        602
# R            439
# PG-13        227
# NR           211
# PG           160
# TV-G         115
# TV-Y7        113
# TV-Y          88
# TV-Y7-FV      62
# G             32
# UR             7
# NC-17          2
# Name: rating, dtype: int64

# %%
df['rating'].value_counts().plot(kind='bar',color = 'green',edgecolor = 'Red')
plt.xlabel('Contents in Netflix')
plt.ylabel('Ratings')
plt.title('Number of contents on Netflix based on Rating')
# Out:
# Text(0.5, 1.0, 'Number of contents on Netflix based on Rating')

# %% [markdown]
# ### Conclusion:
#
# Based on ratings, TV-MA (Mature Audience Only) has more contents.
# So, Adults has more contents in Netflix to look than children.
# Netflix has least contents on the rating NC-17.

# %% [markdown]
# ###

# %% [markdown]
# #### Task 2: Plot a graph showing the number of TV Shows and Movies across different type of Rating.

# %%
df.columns
# Out:
# Index(['show_id', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description',
#        'type'],
#       dtype='object')

# %%
df['rating'].groupby(df['type']).value_counts().plot(kind = 'bar',color = 'black',edgecolor = 'red')
plt.xlabel('TV Shows vs Movies in Netflix')
plt.ylabel('Ratings')
plt.title('Number of TV Shows and Movies across different type of Rating')
# Out:
# Text(0.5, 1.0, 'Number of TV Shows and Movies across different type of Rating')

# %%
df['type'].groupby(df['rating']).value_counts().plot(kind = 'bar',color = 'black',edgecolor = 'red')
plt.xlabel('TV Shows vs Movies in Netflix')
plt.ylabel('Ratings')
plt.title('Number of TV Shows and Movies across different type of Rating')
# Out:
# Text(0.5, 1.0, 'Number of TV Shows and Movies across different type of Rating')

# %% [markdown]
# ### Conclusion:
# Thus, to specify the contents based on ratings in Netflix, I conclude that overall, "Movies with ratings TV-MA" has more
# contents than all other ratings as well as the TV-Shows.
# In TV-Shows, we see that "TV-14" which children under 14 are not suitable for contents are more in Netflix.
#
# "NC-17" in Movies and "G" in TV-Show has the least contents in Netflix.

# %% [markdown]
# #### Task 3: Compare India, US, Japan, Spain, UK & Canada to check which country produces highest TV Show and Movies.

# %%
df.columns
# Out:
# Index(['show_id', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description',
#        'type'],
#       dtype='object')

# %%
country = ['India','United States','Japan','Spain','United Kingdom','Canada']
ctry = df.loc[df['country'].isin(country)]
ctry.head()
# Out:
#      show_id                    title         director  \
# 2   81213894          The Zoya Factor  Abhishek Sharma
# 11  81094391     Sugar Rush Christmas              NaN
# 15  80990849  The Movies That Made Us              NaN
# 16  81033086             Holiday Rush     Leslie Small
# 17  80156799                   Levius              NaN
#
#                                                  cast        country  \
# 2   Sonam Kapoor, Dulquer Salmaan, Sanjay Kapoor, ...          India
# 11        Hunter March, Candace Nelson, Adriano Zumbo  United States
# 15                                                NaN  United States
# 16  Romany Malco, Sonequa Martin-Green, Darlene Lo...  United States
# 17  Nobunaga Shimazaki, Junichi Suwabe, Takahiro S...          Japan
#
#            date_added  release_year rating  duration  \
# 2   November 30, 2019          2019  TV-14   135 min
# 11  November 29, 2019          2019  TV-PG  1 Season
# ...

# %%
df['type'].groupby(ctry['country']).value_counts().plot(kind = 'bar',color = 'white',edgecolor = 'red',lw = 2)
plt.xlabel('TV Shows vs Movies Country Specific')
plt.ylabel('Ratings')
plt.title('Number of TV Shows and Movies across different type of Countries')
# Out:
# Text(0.5, 1.0, 'Number of TV Shows and Movies across different type of Countries')

# %%
ctry['country'].groupby(df['type']).value_counts().plot(kind = 'bar',color = 'cyan',edgecolor = 'red',lw=1.2)
plt.xlabel('TV Shows vs Movies Country Specific')
plt.ylabel('Ratings')
plt.title('Number of TV Shows and Movies across different type of Countries')
# Out:
# Text(0.5, 1.0, 'Number of TV Shows and Movies across different type of Countries')

# %% [markdown]
# ### Conclusion:
# I conclude that Netflix in United States tops the Movie Contents followed by India.
# And in TV Shows also USA tops the number the contents followed by United Kingdom.
#
# Thus, movies contents in Japan and TV-show contents in Spain has fewer contents in Netflix.

# %% [markdown]
# #### Task 4: Plot a graph showing the number of TV Shows and Movies added to Netflix every year.

# %%
df.columns
# Out:
# Index(['show_id', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description',
#        'type'],
#       dtype='object')

# %%
Date = pd.to_datetime(df['date_added'])
year = Date.dt.yearx

# %%
df['year'] = Date.dt.year

# %%
df.head(2)
# Out:
#     show_id                                title                    director  \
# 0  81193313                            Chocolate                         NaN
# 1  81197050  Guatemala: Heart of the Mayan World  Luis Ara, Ignacio Jaunsolo
#
#                                                 cast      country  \
# 0  Ha Ji-won, Yoon Kye-sang, Jang Seung-jo, Kang ...  South Korea
# 1                                  Christian Morales          NaN
#
#           date_added  release_year rating  duration  \
# 0  November 30, 2019          2019  TV-14  1 Season
# 1  November 30, 2019          2019   TV-G    67 min
#
#                                            listed_in  \
# 0  International TV Shows, Korean TV Shows, Roman...
# 1                Documentaries, International Movies
#
#                                          description     type    year
# 0  Brought together by meaningful meals in the pa...  TV Show  2019.0
# ...

# %%
df['year'].groupby(df['type']).value_counts()
# Out:
# type     year
# Movie    2019.0    1367
#          2018.0    1290
#          2017.0     913
#          2016.0     264
#          2015.0      58
#          2014.0      19
#          2011.0      13
#          2013.0       6
#          2012.0       4
#          2009.0       2
#          2008.0       1
#          2010.0       1
# TV Show  2019.0     476
#          2018.0     339
#          2017.0     271
#          2016.0     148
#          2015.0      16
#          2012.0       3
#          2013.0       3
#          2008.0       1
# Name: year, dtype: int64

# %%
#showing the number of TV Shows and Movies added to Netflix every year.

df['type'].groupby(df['year']).value_counts().plot(kind='bar',color = 'orange',edgecolor = 'black',lw = 1.0,linestyle = '-')
plt.xlabel('TV Shows vs Movies year_wise')
plt.ylabel('Ratings')
plt.title('Number of TV Shows and Movies across different years')
# Out:
# Text(0.5, 1.0, 'Number of TV Shows and Movies across different years')

# %%
df['year'].groupby(df['type']).value_counts().plot(kind='bar',color = 'blue',edgecolor = 'black',lw = 1.0,linestyle = '--')
plt.xlabel('TV Shows vs Movies year_wise')
plt.ylabel('Ratings')
plt.title('Number of TV Shows and Movies across different years')
# Out:
# Text(0.5, 1.0, 'Number of TV Shows and Movies across different years')

# %%
df['year'].groupby(df['type']).value_counts()
# Out:
# type     year
# Movie    2019.0    1367
#          2018.0    1290
#          2017.0     913
#          2016.0     264
#          2015.0      58
#          2014.0      19
#          2011.0      13
#          2013.0       6
#          2012.0       4
#          2009.0       2
#          2008.0       1
#          2010.0       1
# TV Show  2019.0     476
#          2018.0     339
#          2017.0     271
#          2016.0     148
#          2015.0      16
#          2012.0       3
#          2013.0       3
#          2008.0       1
# Name: year, dtype: int64

# %% [markdown]
# ### Conclusion:
# We can conclude that contents are gradually added each year at the rate of 0.25% to 0.50%. There is no decrease in between the years rather it is a gradual increase happening over the years in both TV Shows as well as Movies.

# %% [markdown]
# #### Task 5: In 2019, Find out if Netflix has added more TV Shows or Movies to their platform and represent the same visually.

# %%
year_2019 = df[df['year'] == 2019]

# %%
year_2019['type'].value_counts().plot(kind = 'bar', color = 'cyan',edgecolor = 'orange', width = 0.3, lw = 3.0,linestyle = '--')
plt.xlabel('Movies vs TV Shows')
plt.title('Movies vs TV Shows in Netflix')
# Out:
# Text(0.5, 1.0, 'Movies vs TV Shows in Netflix')

# %% [markdown]
# ### Conclusion:
# It is obvious that in 2019, Netflix has more contents on "movies" than "TV-Shows".
